# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
test_types = [
    "Motorettes (AC-GND;\nphase-to-phase)",
    "Motorettes (AC-GND;\nturn-to-turn)",
    "Twisted Pairs\n(AC-GND)",
    "Power Module\n(AC-GND)"
]

electrical_pdiv = [902, 629, 668, 1088]
ae_hits_pdiv    = [1290, 1188, 716, 1004]
ae_spec_pdiv    = [811, 842, 682, 511]

# Bar positions
x = np.arange(len(test_types))
width = 0.25  # bar width

# Custom colors (change these as you like)
colors = {
    "electrical": "tab:blue",
    "ae_hits":    "tab:purple",
    "ae_spec":    "tab:red"
}

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

# Bars (and place number labels on top)
bars1 = ax.bar(x - width, electrical_pdiv, width, label="Electrical PDIV", color=colors["electrical"])
bars2 = ax.bar(x,         ae_hits_pdiv,    width, label="AE hits-derived PDIV", color=colors["ae_hits"])
bars3 = ax.bar(x + width, ae_spec_pdiv,    width, label="AE spectral-derived PDIV", color=colors["ae_spec"])

ax.bar_label(bars1, padding=3)
ax.bar_label(bars2, padding=3)
ax.bar_label(bars3, padding=3)

# Formatting
ax.set_xlabel("Test Type")
ax.set_ylabel("PDIV (V)")
ax.set_xticks(x)
ax.set_xticklabels(test_types)
ax.legend()

ax.set_axisbelow(True)
ax.grid(True, axis="y", linestyle="--", alpha=0.4)

ax.set_title(
    "Comparison of PDIV Measurement Methods",
    fontsize=14,
    pad=12
)

max_value = max(max(electrical_pdiv), max(ae_hits_pdiv), max(ae_spec_pdiv))
ax.set_ylim(0, max_value * 1.2)

plt.tight_layout()
plt.show()

# %%
# Twisted Pairs

# Data
twisted_pairs = [
    f"{i+1}" for i in range(11)
]

tp_electrical_pdiv = [708.6, 628.2, 618.5, 698.2, 648.8, 655.5, 719.5, 732.2, 654.2, 644.2, 640.8]
tp_ae_hits_pdiv    = [707.6,642.7,677.2,732.7,818.7,716.9,746.0,848.2,660.2,665.2,660.7]
tp_ae_spec_pdiv    = [717.5,623.0,642.2,706.1,705.2,697.8,736.2,729.2,646.0,654.3,646.2]

# Bar positions
x = np.arange(len(twisted_pairs))
width = 0.25  # bar width

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

# Bars (and place number labels on top)
tp_bars1 = ax.bar(x - width, tp_electrical_pdiv, width, label="Electrical PDIV", color=colors["electrical"])
tp_bars2 = ax.bar(x,         tp_ae_hits_pdiv,    width, label="AE hits-derived PDIV", color=colors["ae_hits"])
tp_bars3 = ax.bar(x + width, tp_ae_spec_pdiv,    width, label="AE spectral-derived PDIV", color=colors["ae_spec"])

# Formatting
ax.set_xlabel("Twisted Pair Number")
ax.set_ylabel("PDIV (V)")
ax.set_xticks(x)
ax.set_xticklabels(twisted_pairs)
ax.legend()

ax.set_axisbelow(True)
ax.grid(True, axis="y", linestyle="--", alpha=0.4)

ax.set_title(
    "Comparison of PDIV Measurement Methods on Twisted Pairs",
    fontsize=14,
    pad=12
)

max_value = max(max(tp_electrical_pdiv), max(tp_ae_hits_pdiv), max(tp_ae_spec_pdiv))
ax.set_ylim(0, max_value * 1.2)

plt.tight_layout()
plt.show()

# %%
# Phase-to-Phase Motorettes

# Data
motorettes = [
    f"Coils {i+1} & {i+2}" for i in range(7)
]

p2p_electrical_pdiv = [821.6605913,688.8269395,579.558171,1485.324853,776.4632895,738.1942925,577.8634725]
p2p_ae_hits_pdiv    = [2211.551424,1577.747333,1373.562275,1334.097966,843.832067,745.9782505,672.463933]
p2p_ae_spec_pdiv    = [1899.429328,955.421693,584.3410205,650.4496925,438.336682,319.0177795,380.4430725]

# Bar positions
x = np.arange(len(motorettes))
width = 0.25  # bar width

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

# Bars (and place number labels on top)
p2p_bars1 = ax.bar(x - width, p2p_electrical_pdiv, width, label="Electrical PDIV", color=colors["electrical"])
p2p_bars2 = ax.bar(x,         p2p_ae_hits_pdiv,    width, label="AE hits-derived PDIV", color=colors["ae_hits"])
p2p_bars3 = ax.bar(x + width, p2p_ae_spec_pdiv,    width, label="AE spectral-derived PDIV", color=colors["ae_spec"])

# Formatting
ax.set_xlabel("Motorette Coils")
ax.set_ylabel("PDIV (V)")
ax.set_xticks(x)
ax.set_xticklabels(motorettes)
ax.legend()

ax.set_axisbelow(True)
ax.grid(True, axis="y", linestyle="--", alpha=0.4)

ax.set_title(
    "Comparison of PDIV Measurement Methods on Motorettes Tested Phase-to-Phase",
    fontsize=14,
    pad=12
)

max_value = max(max(p2p_electrical_pdiv), max(p2p_ae_hits_pdiv), max(p2p_ae_spec_pdiv))
ax.set_ylim(0, max_value * 1.2)

plt.tight_layout()
plt.show()

# %%
# Turn-to-Turn Motorettes

# Data
motorettes = [
    f"Coil {i+1}" for i in range(8)
]

t2t_electrical_pdiv = [734.720614,
608.0345073,
593.4507165,
1061.41196,
456.267321,
632.7846285,
542.078906,
642.855102]
t2t_ae_hits_pdiv    = [1602.825444,
1189.529401,
1360.650179,
1320.633361,
1142.371689,
1077.915,
1319.05049,
1080.469771]
t2t_ae_spec_pdiv    = [1132.550473,
867.697474,
883.1060895,
759.7955037,
1095.787202,
805.2827345,
1020.54823,
824.7643915]

# Bar positions
x = np.arange(len(motorettes))
width = 0.25  # bar width

# Plot
fig, ax = plt.subplots(figsize=(10, 5))

# Bars (and place number labels on top)
t2t_bars1 = ax.bar(x - width, t2t_electrical_pdiv, width, label="Electrical PDIV", color=colors["electrical"])
t2t_bars2 = ax.bar(x,         t2t_ae_hits_pdiv,    width, label="AE hits-derived PDIV", color=colors["ae_hits"])
t2t_bars3 = ax.bar(x + width, t2t_ae_spec_pdiv,    width, label="AE spectral-derived PDIV", color=colors["ae_spec"])

# Formatting
ax.set_xlabel("Motorette Coils")
ax.set_ylabel("PDIV (V)")
ax.set_xticks(x)
ax.set_xticklabels(motorettes)
ax.legend()

ax.set_axisbelow(True)
ax.grid(True, axis="y", linestyle="--", alpha=0.4)

ax.set_title(
    "Comparison of PDIV Measurement Methods on Motorettes Tested Turn-to-Turn",
    fontsize=14,
    pad=12
)

max_value = max(max(t2t_electrical_pdiv), max(t2t_ae_hits_pdiv), max(t2t_ae_spec_pdiv))
ax.set_ylim(0, max_value * 1.2)

plt.tight_layout()
plt.show()
